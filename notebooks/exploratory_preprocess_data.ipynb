# %%
def read_weights(file,weight_label="last_params") ->list[np.ndarray[:,:]]:
    with open(file) as f:

        data = json.load(f)

    return data["last_params"]


data = read_weights("/Users/dlakhdar/physics/repos/natural-quantization/data/quantum_nn_rotation_angles/mnist_a0.5_lr-2_shots20_width16.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import json
# ----> 3 def read_weights(file,weight_label="last_params") ->list[np.ndarray[:,:]]:
#       4     with open(file) as f:
#       6         data = json.load(f)
#
# NameError: name 'np' is not defined

# %%
import json
import numpy as np
import matplotlib.pyplot as plt


with open(f"../data/mnist_data/mnist_data_reduced.json") as f:
        data = json.load(f)

test_set = data["test_set"]
    # print(f"data:\n {test_set[0][0]}")
x_test = [np.array(d[0]) for d in test_set]

# %%
plt.imshow(x_test[0].reshape(28,28))
plt.xticks([])   # remove x-axis ticks
plt.yticks([])
# Out:
# ([], [])

# %%
plt.imshow(x_test[6929].reshape(28,28))
plt.xticks([])   # remove x-axis ticks
plt.yticks([])
# Out:
# ([], [])

# %%
plt.imshow(x_test[1901].reshape(28,28))
plt.xticks([])   # remove x-axis ticks
plt.yticks([])
# Out:
# ([], [])
