# %%
import numpy as np
import os 
import matplotlib.pyplot as plt


binomial_error = lambda p,N : (p*(1-p)/N)**(1/2)

def split_chunks(lst, n):
    """Split a list into chunks of size n."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]
        
# 3) Define a small recursive converter that turns any np.generic into a native Python number:
def convert_to_native(obj):
    if isinstance(obj, np.generic):
        return obj.item()   # e.g. np.int64 -> Python int; np.float64 -> Python float
    elif isinstance(obj, list):
        return [convert_to_native(x) for x in obj]
    elif isinstance(obj, tuple):
        return tuple(convert_to_native(x) for x in obj)
    else:
        return obj
    

working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/single_qubit/run3"

def analysis(working_dir,experiment_dir,file_index: tuple,):

 
    files = os.listdir(os.path.join(working_dir,experiment_dir))
    # files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
    files.sort()

    start,end = *file_index
    files = files[start:end]
    print(files)
    data = []
    for file in files:
        file = os.path.join(working_dir, experiment_dir, file)
        with open(file, "r") as f:
            text = f.read()  # disable built-ins for safety)                    )
            converted = convert_to_native(text)
            namespace = {"np": np}
            evaluated_data = eval(
                text,
                {"__builtins__": None},   # disable built-ins for safety
                {"array": np.array}       # map the name 'array' to numpy's array constructor
            )
            converted = convert_to_native(evaluated_data)
            data.append(converted)

    bad_data = sum(data, []) 
    bad_data
    data = sum(data, []) 

    bad_new_data = []

    for d in bad_data:
    bad_new_data.append(d[-1])

    bad_acc = []
    for i,digit in enumerate(bad_new_data):
        for da in digit:
            print(np.mean(np.array(da)==2))
            bad_acc.append(np.mean(np.array(da)==2))

    binomial_error(np.array(bad_acc), len(bad_new_data[0][0]))

    
    # plt.plot(noises,acc,label="validation rate: NY",marker='o')
# plt.plot(noises,bad_acc,label="simulated validation rate: YY",marker='x')

# %%
data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(text, namespace)
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])

len(new_data[0][0])
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[150], line 4
#       2 for file in files:
#       3      file = os.path.join(working_dir, experiment_dir, file)
# ----> 4      with open(file, "r") as f:
#       5         text = f.read()  # disable built-ins for safety)                    )
#       6         converted = convert_to_native(text)
#
# File ~/physics/copy_repos/natural-quantization/.qnn/lib/python3.13/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# ...

# %%
binomial_error = lambda p,N : (p*(1-p)/N)**(1/2)

accuracy=[]
for d in new_data:
    accuracy.append(np.mean(np.array(d)==2))

errors = binomial_error(np.array(accuracy), len(new_data[0][0]))
noises = list(range(0,100,10))
# Out:
# 96

# %%
plt.figure(figsize=(15,8))
plt.title("Validation Rate vrs. Quatumness: a=0.0, 16 Qubits, 3 Layers, 96 Samples per noise level")
plt.plot(noises,accuracy,label="simulated validation rate",marker='o',color="blue")
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=accuracy,yerr=errors,fmt='o',capsize=4,
ecolor="orange",barsabove=False,
label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.xticks(np.arange(0, 101, 10))
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# Text(0, 0.5, 'validation rate')

# %%
# 4) Apply the converter
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise_test/run2"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()


data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(text, namespace)
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])

digits = list(split_chunks(new_data,10))

# %%
accuracies= []
for i,digit in enumerate(digits):
    accuracy=[]
    for da in digit:
        accuracy.append(np.mean(np.array(da)==true_labels[i]))

    accuracies.append(accuracy)

accuracies
# Out:
# [[np.float64(0.9375),
#   np.float64(0.9375),
#   np.float64(0.9375),
#   np.float64(0.96875),
#   np.float64(0.90625),
#   np.float64(0.875),
#   np.float64(0.8125),
#   np.float64(0.8125),
#   np.float64(0.90625),
#   np.float64(0.9375)],
#  [np.float64(0.46875),
#   np.float64(0.5),
#   np.float64(0.53125),
#   np.float64(0.5),
#   np.float64(0.34375),
#   np.float64(0.3125),
#   np.float64(0.375),
#   np.float64(0.3125),
#   np.float64(0.28125),
#   np.float64(0.3125)],
#  [np.float64(1.0),
#   np.float64(0.96875),
#   np.float64(0.90625),
#   np.float64(0.9375),
#   np.float64(0.96875),
#   np.float64(0.84375),
#   np.float64(0.84375),
#   np.float64(0.8125),
#   np.float64(0.84375),
#   np.float64(0.75)],
#  [np.float64(0.875),
#   np.float64(0.71875),
#   np.float64(0.90625),
#   np.float64(0.9375),
#   np.float64(0.8125),
#   np.float64(0.875),
#   np.float64(0.78125),
#   np.float64(0.90625),
#   np.float64(0.71875),
#   np.float64(0.78125)],
#  [np.float64(0.96875),
# ...

# %%
plt.figure(figsize=(15,8))
plt.title("Validation Rate vrs. Quatumness: a=0.0, 16 Qubits, 3 Layers, 96 Samples per noise level")
for i,accuracy in enumerate(accuracies):
    plt.plot(noises,accuracy,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
    plt.errorbar(x=noises,y=accuracy,yerr=errors,fmt='o',capsize=4,
ecolor="orange",barsabove=False,
label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.xticks(np.arange(0, 101, 10))
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# Text(0, 0.5, 'validation rate')

# %%
true_labels = [7,2,1,0,4]
accuracy = []
for i,d in enumerate(new_data):
    d = np.array(d)
    acc = np.mean(d==true_labels[i])
    accuracy.append(acc)

# %%
accuracy
# Out:
# [np.float64(0.903125),
#  np.float64(0.39375),
#  np.float64(0.8875),
#  np.float64(0.83125),
#  np.float64(0.91875)]

# %%
# 4) Apply the converter
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise_test/run3"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

files=files[:20]

data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(text, namespace)
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])

# %%
noises = list(range(10, 1000, 50))
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==7))

errors = binomial_error(np.array(acc), len(new_data[0][0]))

plt.figure(figsize=(15,8))
plt.title("Deterioration of Validation by Noise Level: a=0.5, 16 Qubits, 3 Layers, 32 Samples per noise level")
plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o',capsize=4,
ecolor="orange",barsabove=False,
label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# 0.875
# 0.9375
# 0.84375
# 0.71875
# 0.625
# 0.53125
# 0.59375
# 0.4375
# 0.53125
# 0.375
# 0.34375
# 0.46875
# 0.4375
# 0.21875
# 0.3125
# 0.25
# 0.28125
# 0.25
# 0.1875
# 0.25
# Text(0, 0.5, 'validation rate')

# %%
# 4) Apply the converter
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/single_qubit/run3"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

files = files[4:]

data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(text, namespace)
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])


noises = [0,10,20,50,100]
print(noises)
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==7))

errors = binomial_error(np.array(acc), len(new_data[0][0]))

plt.figure(figsize=(15,8))
plt.title("Deterioration of Validation by Noise Level: a=0.5, 16 Qubits, 3 Layers, 32 Samples per noise level")
plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o',capsize=4,
ecolor="orange",barsabove=False,
label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[183], line 17
#      15 converted = convert_to_native(text)
#      16 namespace = {"np": np}
# ---> 17 evaluated_data = eval(text, namespace)
#      18 converted = convert_to_native(evaluated_data)
#      19 data.append(converted)
#
# File <string>:1
#
# NameError: name 'array' is not defined

# %%
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise_test/run4"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

print

data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(
            text,
            {"__builtins__": None},   # disable built-ins for safety
            {"array": np.array}       # map the name 'array' to numpy's array constructor
        )
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 
new_data = []

for d in data:
    new_data.append(d[-1])

noises = [0,10,20,50,100]
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        # print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==2))

print(acc)

errors = binomial_error(np.array(acc), len(new_data[0][0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[184], line 14
#      12 converted = convert_to_native(text)
#      13 namespace = {"np": np}
# ---> 14 evaluated_data = eval(
#      15     text,
#      16     {"__builtins__": None},   # disable built-ins for safety
#      17     {"array": np.array}       # map the name 'array' to numpy's array constructor
#      18 )
#      19 converted = convert_to_native(evaluated_data)
#      20 data.append(converted)
#
# File <string>:1
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.figure(figsize=(15,8))
plt.title("Deterioration of Validation by Noise Level: a=0.5, 16 Qubits, 3 Layers, 32 Samples per noise level")
plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o',capsize=4,
ecolor="orange",barsabove=False,
label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[172], line 3
#       1 plt.figure(figsize=(15,8))
#       2 plt.title("Deterioration of Validation by Noise Level: a=0.5, 16 Qubits, 3 Layers, 32 Samples per noise level")
# ----> 3 plt.plot(noises,acc,label="simulated validation rate",marker='o')
#       4 # plt.scatter(As,accuracies,color="orange")
#       5 plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o',capsize=4,
#       6 ecolor="orange",barsabove=False,
#       7 label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
#
# File ~/physics/copy_repos/natural-quantization/.qnn/lib/python3.13/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# ...

# %%
# 4) Apply the converter

import numpy as np
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/single_qubit/run4"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()


data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(
            text,
            {"__builtins__": None},   # disable built-ins for safety
            {"array": np.array}       # map the name 'array' to numpy's array constructor
        )
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])


noises = [0,10,20,50,100]
print(noises)
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==7))

errors = binomial_error(np.array(acc), len(new_data[0][0]))

plt.figure(figsize=(15,8))
plt.title(r"Deterioration of Validation by Noise Level: $R_x(\pi/2)$ 96 Samples per noise level")
plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o',capsize=4,
ecolor="orange",barsabove=False,
label=r"error : $\sigma$=$\sqrt{\frac{p(1-p)}{N}}$")
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# [0, 10, 20, 50, 100]
# 0.9166666666666666
# 0.7708333333333334
# 0.4895833333333333
# 0.2708333333333333
# 0.15625
# Text(0, 0.5, 'validation rate')

# %%
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/single_qubit/run1"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

print(files)
data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(
            text,
            {"__builtins__": None},   # disable built-ins for safety
            {"array": np.array}       # map the name 'array' to numpy's array constructor
        )
        converted = convert_to_native(evaluated_data)
        data.append(converted)

bad_data = sum(data, []) 
bad_data
data = sum(data, []) 

bad_new_data = []

for d in bad_data:
   bad_new_data.append(d[-1])

bad_acc = []
for i,digit in enumerate(bad_new_data):
    for da in digit:
        print(np.mean(np.array(da)==2))
        bad_acc.append(np.mean(np.array(da)==2))

bad_errors = binomial_error(np.array(bad_acc), len(bad_new_data[0][0]))

noises = [0,5,10,20,10500]

plt.figure(figsize=(15,8))
plt.title(r"Deterioration of Validation by Noise Level: $R_x(\pi/2)$ 96 Samples per noise level")
# plt.plot(noises,acc,label="validation rate: NY",marker='o')
# plt.plot(noises,bad_acc,label="simulated validation rate: YY",marker='x')

# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o-',capsize=4,barsabove=False,label="NY")
plt.errorbar(x=noises,y=bad_acc,yerr=bad_errors,fmt='x--',capsize=4,barsabove=False,label="YY")
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# ['2025-06-12_20:00:19.180528_index_6929_noise_20_results.txt', '2025-06-12_20:39:07.443558_index_6929_noise_50_results.txt']
# 0.09375
# 0.07291666666666667
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[220], line 50
#      45 # plt.plot(noises,acc,label="validation rate: NY",marker='o')
#      46 # plt.plot(noises,bad_acc,label="simulated validation rate: YY",marker='x')
#      47
#      48 # plt.scatter(As,accuracies,color="orange")
#      49 plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o-',capsize=4,barsabove=False,label="NY")
# ---> 50 plt.errorbar(x=noises,y=bad_acc,yerr=bad_errors,fmt='x--',capsize=4,barsabove=False,label="YY")
#      51 # plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
#      52 plt.xlabel("noise level (pairs of extraneous unitaries)")
#
# ...

# %%
# Out:
# ['2025-06-13_22:14:26.297248_index_6929_noise_0_results.txt', '2025-06-13_22:21:17.270338_index_6929_noise_10_results.txt', '2025-06-13_22:28:13.055727_index_6929_noise_20_results.txt', '2025-06-13_22:37:36.681661_index_6929_noise_50_results.txt', '2025-06-13_22:47:49.699230_index_6929_noise_100_results.txt']
# 0.8854166666666666
# 0.78125
# 0.5104166666666666
# 0.19791666666666666
# 0.14583333333333334
# Text(0, 0.5, 'validation rate')

# %%
# 4) Apply the converter

import numpy as np
working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/two_qubit/run1"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(
            text,
            {"__builtins__": None},   # disable built-ins for safety
            {"array": np.array}       # map the name 'array' to numpy's array constructor
        )
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])


noises = [0,20,50,100,200,400,500]
print(noises)
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==7))

errors = binomial_error(np.array(acc), len(new_data[0][0]))

plt.figure(figsize=(15,8))
plt.title("Validation by Noise Level: ECR gates added at a=.5")
# plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o--',capsize=4,color="black",
ecolor="grey",barsabove=False)
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# [0, 20, 50, 100, 200, 400, 500]
# 0.875
# 0.84375
# 0.8020833333333334
# 0.84375
# 0.7708333333333334
# 0.7708333333333334
# 0.7708333333333334
# /var/folders/04/2cqfhcv133s3gbkf3b35tnkr0000gn/T/ipykernel_19939/1821630806.py:51: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'validation rate')

# %%
# 4) Apply the converter

working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/two_qubit/simulation"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(text, namespace)
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])


noises = [0,10,100,200,400,500]
print(noises)
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==7))

errors = binomial_error(np.array(acc), len(new_data[0][0]))

plt.figure(figsize=(15,8))
plt.title("Validation by Noise Level: ECR gates added at a=.5")
# plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o--',capsize=4,color="black",
ecolor="grey",barsabove=False)
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.xticks(noises)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# [0, 10, 100, 200, 400, 500]
# 1.0
# 0.46875
# 0.09375
# 0.0625
# 0.0625
# 0.09375
# /var/folders/04/2cqfhcv133s3gbkf3b35tnkr0000gn/T/ipykernel_19939/3019831509.py:46: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'validation rate')

# %%
# 4) Apply the converter

working_dir="/Users/dlakhdar/physics/copy_repos/natural-quantization/data/experiment_data"
experiment_dir="noise/two_qubit/simulation/run2"
files = os.listdir(os.path.join(working_dir,experiment_dir))
# files = [os.path.join(working_dir,experiment_dir,f"run{i}", file) for file in files]
files.sort()

data = []
for file in files:
     file = os.path.join(working_dir, experiment_dir, file)
     with open(file, "r") as f:
        text = f.read()  # disable built-ins for safety)                    )
        converted = convert_to_native(text)
        namespace = {"np": np}
        evaluated_data = eval(text, namespace)
        converted = convert_to_native(evaluated_data)
        data.append(converted)

data = sum(data, []) 

new_data = []

for d in data:
    new_data.append(d[-1])


noises = [0,10,50,100,200]
print(noises)
acc= []
for i,digit in enumerate(new_data):
    for da in digit:
        print(np.mean(np.array(da)==7))
        acc.append(np.mean(np.array(da)==7))

errors = binomial_error(np.array(acc), len(new_data[0][0]))

plt.figure(figsize=(15,8))
plt.title("Validation by Noise Level: ECR gates added at a=.5")
# plt.plot(noises,acc,label="simulated validation rate",marker='o')
# plt.scatter(As,accuracies,color="orange")
plt.errorbar(x=noises,y=acc,yerr=errors,fmt='o--',capsize=4,color="black",
ecolor="grey",barsabove=False)
# plt.plot(0.0,.48,'ro',label="validation on quantum device",markersize=5)
plt.xlabel("noise level (pairs of extraneous unitaries)")
plt.legend()
plt.grid()
plt.xticks(noises)
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylim(0, 1)
plt.ylabel("validation rate")
# Out:
# [0, 10, 50, 100, 200]
# 0.9375
# 0.5
# 0.25
# 0.125
# 0.09375
# /var/folders/04/2cqfhcv133s3gbkf3b35tnkr0000gn/T/ipykernel_19939/378988044.py:46: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'validation rate')
